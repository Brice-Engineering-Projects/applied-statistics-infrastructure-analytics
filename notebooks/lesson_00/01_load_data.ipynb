# %%
from src.lesson_00.functions import load_data, descriptive_statistics
from pathlib import Path

# %%
DATA = Path("../../data/raw/annual_peak_flow.csv")
df = load_data(DATA)
# Out:
# Dataset has been loaded as a Pandas Dataframe

# %%
df.head()
# Out:
#    year  peak_flow_cfs
# 0  2005            412
# 1  2006            437
# 2  2007            455
# 3  2008            472
# 4  2009            489

# %%
df.tail()
# Out:
#     year  peak_flow_cfs
# 15  2020            691
# 16  2021            724
# 17  2022            771
# 18  2023            845
# 19  2024            936

# %%
print(df.dtypes)
# Out:
# year             int64
# peak_flow_cfs    int64
# dtype: object

# %%
stats = descriptive_statistics(df)
print(stats)
# Out:
# {'observations': 20, 'sample_mean': 599.25, 'sample_median': 570.0, 'sample_max': 936, 'sample_min': 412, 'sample_range': 524, 'sample_variance': 19401.25, 'sample_standard_deviation': 139.28836993805334}
